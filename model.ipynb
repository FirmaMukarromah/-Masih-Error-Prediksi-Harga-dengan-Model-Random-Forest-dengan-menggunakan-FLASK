# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve, recall_score
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, GradientBoostingClassifier
import pickle

# %%
tv = pd.read_csv('tvfix.csv', sep=";")
tv.head()
# Out:
#                      produk     merek tipe  ukuran    harga
# 0       Polytron PLD32T7511  Polytron  LED      32  1648000
# 1   Sharp AQUOS LC-24LE170i     Sharp  LED      24  1091200
# 2   Sharp AQUOS LC-24LE175i     Sharp  LED      24   400000
# 3  Sharp AQUOS LC-32SA4100i     Sharp  LED      32  1945000
# 4        Polytron PLD32T710  Polytron  LED      32  1890000

# %%
tv.dtypes
# Out:
# produk    object
# merek     object
# tipe      object
# ukuran     int64
# harga      int64
# dtype: object

# %%
tv["produk"].value_counts()
# Out:
# TCL D2700                      6
# Samsung UA55JS7200             1
# Panasonic VIERA TH-43C305G     1
# Samsung QA75Q9F                1
# Sharp AQUOS LC-40LE265M        1
# AKARI SC-52V40                 1
# Changhong Led29A6500           1
# LG 60LF630T                    1
# TOSHIBA REGZA 49L3750          1
# Changhong 22C2600              1
# Sharp AQUOS LC-24LE170i        1
# Sharp AQUOS LC-24LE175i        1
# LG 42UB700T                    1
# LG 43UF640T                    1
# TOSHIBA REGZA 24L3650          1
# LG 79UF770T                    1
# Sharp AQUOS LC-40LE185i        1
# Sharp AQUOS LC-58UE1M          1
# Coocaa 40D3A                   1
# Samsung UA32K4100              1
# Panasonic VIERA TH-43F305G     1
# Samsung PS43D450A2M            1
# LG 49LF630T                    1
# LG 32LH500D                    1
# Samsung UA32F4000              1
# LG OLed65B6T                   1
# Panasonic VIERA TH-55EX600G    1
# AKARI LE-50D88ID               1
# LG 49UH610T                    1
# Sharp AQUOS LC-40LE380X        1
#                               ..
# LG 32LN5100                    1
# LG 49LF540T                    1
# Sony BRAVIA KDL-40R350B        1
# Samsung UA40MU6100             1
# Samsung QA65Q8C                1
# Samsung QA65Q9F                1
# Polytron PLD22D1150            1
# LG 49UK6300PTE                 1
# Samsung UA32J5100              1
# Samsung UA48H8000AK            1
# TOSHIBA REGZA 43L5650          1
# Sharp AQUOS 4T-C60AH1X         1
# LG 43UJ652T                    1
# Sony BRAVIA KD-55X8500D        1
# TOSHIBA REGZA 49U7650          1
# Changhong 40E6000HFT           1
# Samsung UA32FH4003             1
# LG 32LB530A                    1
# LG 55UB950T                    1
# Samsung UA48JU6000             1
# LG 43UH650T                    1
# LG 49LF550T                    1
# AKARI LE-4099T2                1
# LG 65UF670T                    1
# Sony BRAVIA KDL-60W600B        1
# LG 86UK6500PTB                 1
# Sharp AQUOS LC-32LE265i        1
# Changhong 32E6000i             1
# LG 28TK430V-PT                 1
# LG 55UH615T                    1
# Name: produk, Length: 430, dtype: int64

# %%
def _get_category_mapping(column):
    """ Return the mapping of a category """
    return dict([(cat, code) for code, cat in enumerate(column.cat.categories)])

# %%
tv['produk'] = tv['produk'].astype('category')
produk_mapping = _get_category_mapping(tv['produk'])
tv['produk'] = tv['produk'].cat.codes

# %%
produk_mapping
# Out:
# {'AKARI LE-20K88': 0,
#  'AKARI LE-20V89': 1,
#  'AKARI LE-24K88ID': 2,
#  'AKARI LE-25B88': 3,
#  'AKARI LE-29P57ID': 4,
#  'AKARI LE-29V89': 5,
#  'AKARI LE-3289T2': 6,
#  'AKARI LE-32AK30': 7,
#  'AKARI LE-32D88': 8,
#  'AKARI LE-32K88': 9,
#  'AKARI LE-32M88': 10,
#  'AKARI LE-32P88': 11,
#  'AKARI LE-32V90': 12,
#  'AKARI LE-32V99SM': 13,
#  'AKARI LE-32V99T2': 14,
#  'AKARI LE-4099T2': 15,
#  'AKARI LE-40D88': 16,
#  'AKARI LE-40P88': 17,
#  'AKARI LE-4399T2SB': 18,
#  'AKARI LE-43D99SBS': 19,
#  'AKARI LE-5099T2SB': 20,
#  'AKARI LE-50D88ID': 21,
#  'AKARI LE-50D99SBS': 22,
#  'AKARI LE-55D88S': 23,
#  'AKARI LE-65D88': 24,
#  'AKARI SC-52V32': 25,
#  'AKARI SC-52V40': 26,
#  'AKARI SC-52V43': 27,
#  'AQUA LE24AQT6500T': 28,
#  'AQUA LE24AQT8300': 29,
#  'AQUA LE32AQT6500': 30,
#  'AQUA LE32AQT7000T': 31,
#  'AQUA LE32AQT9000': 32,
#  'AQUA LE40AQT8300': 33,
#  'Changhong 22C2600': 34,
#  'Changhong 32E6000i': 35,
#  'Changhong 40E6000HFT': 36,
#  'Changhong 50E6000HFT': 37,
#  'Changhong L24G3': 38,
#  'Changhong L32H4': 39,
#  'Changhong L32H7': 40,
#  'Changhong LE19868': 41,
#  'Changhong LE19D1000': 42,
#  'Changhong LE24818': 43,
#  'Changhong LE24B1000': 44,
#  'Changhong LE32880': 45,
#  'Changhong LE32D1000': 46,
#  'Changhong LE39B2500': 47,
#  'Changhong LE40D1200': 48,
#  'Changhong Led29A6500': 49,
#  'Changhong Led50D2200': 50,
#  'Changhong U50H7': 51,
#  'Coocaa 24D3A': 52,
#  'Coocaa 32S5C': 53,
#  'Coocaa 32W4': 54,
#  'Coocaa 40D3A': 55,
#  'Coocaa 40S5C': 56,
#  'Coocaa 40S5G': 57,
#  'Coocaa 50G2': 58,
#  'Coocaa 50S5G': 59,
#  'Coocaa Led 24E88': 60,
#  'Coocaa Led 32E20': 61,
#  'Coocaa Led 32E60': 62,
#  'LG 19LS3300': 63,
#  'LG 20LB450A': 64,
#  'LG 20MT48AF-PT': 65,
#  'LG 22MT48AF-PT': 66,
#  'LG 22TK420A-PT': 67,
#  'LG 24LB450A': 68,
#  'LG 24LB452A': 69,
#  'LG 24LF450A': 70,
#  'LG 24MT48AF-PT': 71,
#  'LG 28TK430V-PT': 72,
#  'LG 28TL430V-PT': 73,
#  'LG 29MT45': 74,
#  'LG 29MT47A': 75,
#  'LG 29MT48AF-PT': 76,
#  'LG 32LB530A': 77,
#  'LG 32LB550A': 78,
#  'LG 32LB563D': 79,
#  'LG 32LF20': 80,
#  'LG 32LF520A': 81,
#  'LG 32LF550A': 82,
#  'LG 32LF595D': 83,
#  'LG 32LH500D': 84,
#  'LG 32LH510D': 85,
#  'LG 32LH570D': 86,
#  'LG 32LJ500D': 87,
#  'LG 32LJ550D': 88,
#  'LG 32LK450': 89,
#  'LG 32LK500BPTA': 90,
#  'LG 32LM550BPTA': 91,
#  'LG 32LN5100': 92,
#  'LG 32LS3400': 93,
#  'LG 39LB561T': 94,
#  'LG 39LN5400': 95,
#  'LG 40UB800T': 96,
#  'LG 40UF770T': 97,
#  'LG 42LB550A': 98,
#  'LG 42LB582T': 99,
#  'LG 42LF550A': 100,
#  'LG 42LM6200': 101,
#  'LG 42LN5400': 102,
#  'LG 42PN4500': 103,
#  'LG 42UB700T': 104,
#  'LG 42UB820T': 105,
#  'LG 43LF510T': 106,
#  'LG 43LF540T': 107,
#  'LG 43LH500T': 108,
#  'LG 43LH511T': 109,
#  'LG 43LH540T': 110,
#  'LG 43LH570T': 111,
#  'LG 43LJ500T': 112,
#  'LG 43LJ550T': 113,
#  'LG 43LK5400PTA': 114,
#  'LG 43LM5500PTA': 115,
#  'LG 43LM5700PTC': 116,
#  'LG 43UF640T': 117,
#  'LG 43UF680T': 118,
#  'LG 43UF690T': 119,
#  'LG 43UF770T': 120,
#  'LG 43UH610T': 121,
#  'LG 43UH650T': 122,
#  'LG 43UJ632T': 123,
#  'LG 43UJ652T': 124,
#  'LG 43UK6500PTC': 125,
#  'LG 43UM7100PTA': 126,
#  'LG 43UM7300PTA': 127,
#  'LG 49LB620T': 128,
#  'LG 49LF540T': 129,
#  'LG 49LF550T': 130,
#  'LG 49LF630T': 131,
#  'LG 49LH511T': 132,
#  'LG 49LH540T': 133,
#  'LG 49LH570T': 134,
#  'LG 49LJ510T': 135,
#  'LG 49SJ800T': 136,
#  'LG 49UB820T': 137,
#  'LG 49UF670T': 138,
#  'LG 49UF680T': 139,
#  'LG 49UF850T': 140,
#  'LG 49UH610T': 141,
#  'LG 49UH650T': 142,
#  'LG 49UH770T': 143,
#  'LG 49UJ632T': 144,
#  'LG 49UK6300PTE': 145,
#  'LG 50LB582T': 146,
#  'LG 50UF830T': 147,
#  'LG 55EA970T': 148,
#  'LG 55EG910T': 149,
#  'LG 55LF550T': 150,
#  'LG 55LH575T': 151,
#  'LG 55SJ800T': 152,
#  'LG 55SJ850T': 153,
#  'LG 55SM8100PTA': 154,
#  'LG 55SM8600PTA': 155,
#  'LG 55UB820T': 156,
#  'LG 55UB850T': 157,
#  'LG 55UB950T': 158,
#  'LG 55UF680T': 159,
#  'LG 55UF850T': 160,
#  'LG 55UH600T': 161,
#  'LG 55UH615T': 162,
#  'LG 55UH650T': 163,
#  'LG 55UH770T': 164,
#  'LG 55UH850T': 165,
#  'LG 55UJ632T': 166,
#  'LG 55UJ652T': 167,
#  'LG 60LF630T': 168,
#  'LG 60UB820T': 169,
#  'LG 60UH650T': 170,
#  'LG 60UH770T': 171,
#  'LG 65LF630T': 172,
#  'LG 65SJ850T': 173,
#  'LG 65SM8100PTA': 174,
#  'LG 65SM8600PTA': 175,
#  'LG 65UB930T': 176,
#  'LG 65UB950T': 177,
#  'LG 65UF670T': 178,
#  'LG 65UH615T': 179,
#  'LG 65UH650T': 180,
#  'LG 65UJ632T': 181,
#  'LG 65UJ652T': 182,
#  'LG 75UJ657T': 183,
#  'LG 75UK6500PTB': 184,
#  'LG 79UF770T': 185,
#  'LG 84UB980T': 186,
#  'LG 86SJ957T': 187,
#  'LG 86UH955T': 188,
#  'LG 86UK6500PTB': 189,
#  'LG 98UB980T': 190,
#  'LG M2241A': 191,
#  'LG OLed55B6T': 192,
#  'LG OLed65B6T': 193,
#  'LG OLed65E6T': 194,
#  'Mito 3255': 195,
#  'Panasonic VIERA TH-22D305G': 196,
#  'Panasonic VIERA TH-24E303': 197,
#  'Panasonic VIERA TH-32C305G': 198,
#  'Panasonic VIERA TH-32D302G': 199,
#  'Panasonic VIERA TH-32D306G': 200,
#  'Panasonic VIERA TH-32E302': 201,
#  'Panasonic VIERA TH-32E305': 202,
#  'Panasonic VIERA TH-32F306G': 203,
#  'Panasonic VIERA TH-40F305G': 204,
#  'Panasonic VIERA TH-43C305G': 205,
#  'Panasonic VIERA TH-43E306': 206,
#  'Panasonic VIERA TH-43ES630G': 207,
#  'Panasonic VIERA TH-43EX400': 208,
#  'Panasonic VIERA TH-43EX600G': 209,
#  'Panasonic VIERA TH-43F305G': 210,
#  'Panasonic VIERA TH-49EX400': 211,
#  'Panasonic VIERA TH-49EX600G': 212,
#  'Panasonic VIERA TH-49FX700G': 213,
#  'Panasonic VIERA TH-55E306': 214,
#  'Panasonic VIERA TH-55EX400': 215,
#  'Panasonic VIERA TH-55EX600G': 216,
#  'Philips 24PHA4100S/70': 217,
#  'Philips 32PHA4100S/70': 218,
#  'Philips 32PHT4002S/70': 219,
#  'Philips 39PHA4251S': 220,
#  'Philips 40PFA4150': 221,
#  'Philips 40PFA4160S/98': 222,
#  'Philips 49PFA4300S/70': 223,
#  'Philips 50PUT6002S/70': 224,
#  'Polytron PLD-22D900': 225,
#  'Polytron PLD20D302': 226,
#  'Polytron PLD20D901': 227,
#  'Polytron PLD20D9501': 228,
#  'Polytron PLD22D110': 229,
#  'Polytron PLD22D1150': 230,
#  'Polytron PLD24D800': 231,
#  'Polytron PLD24D810': 232,
#  'Polytron PLD24D901': 233,
#  'Polytron PLD24T810W': 234,
#  'Polytron PLD32D100': 235,
#  'Polytron PLD32D710': 236,
#  'Polytron PLD32D905': 237,
#  'Polytron PLD32T100': 238,
#  'Polytron PLD32T500': 239,
#  'Polytron PLD32T710': 240,
#  'Polytron PLD32T7511': 241,
#  'Polytron PLD40S153': 242,
#  'Polytron PLD40TS853': 243,
#  'Polytron PLD40TV853': 244,
#  'Polytron PLD43S863': 245,
#  'Polytron PLD43V863': 246,
#  'Polytron PLD65D585': 247,
#  'Polytron PLM32B21': 248,
#  'SANYO 24K40': 249,
#  'Samsung 32F5500': 250,
#  'Samsung 40F5000': 251,
#  'Samsung 40F6100': 252,
#  'Samsung 43K5002': 253,
#  'Samsung LA-B530': 254,
#  'Samsung LA19D400': 255,
#  'Samsung LA32B530': 256,
#  'Samsung PS43D450A2M': 257,
#  'Samsung QA55Q70R': 258,
#  'Samsung QA55Q7F': 259,
#  'Samsung QA55Q8C': 260,
#  'Samsung QA65Q70R': 261,
#  'Samsung QA65Q7F': 262,
#  'Samsung QA65Q8C': 263,
#  'Samsung QA65Q9F': 264,
#  'Samsung QA75Q8C': 265,
#  'Samsung QA75Q9F': 266,
#  'Samsung The Frame 2019 QA55LS03': 267,
#  'Samsung UA22H5003': 268,
#  'Samsung UA232J4303': 269,
#  'Samsung UA24H4003': 270,
#  'Samsung UA24H4150': 271,
#  'Samsung UA32D4003': 272,
#  'Samsung UA32EH4003': 273,
#  'Samsung UA32EH4003M': 274,
#  'Samsung UA32F4000': 275,
#  'Samsung UA32FH4003': 276,
#  'Samsung UA32H4000': 277,
#  'Samsung UA32J4003': 278,
#  'Samsung UA32J5100': 279,
#  'Samsung UA32J5500': 280,
#  'Samsung UA32K4100': 281,
#  'Samsung UA40EH5000': 282,
#  'Samsung UA40H5003': 283,
#  'Samsung UA40J5000AK': 284,
#  'Samsung UA40J5100': 285,
#  'Samsung UA40J6300': 286,
#  'Samsung UA40JU6600': 287,
#  'Samsung UA40K6300': 288,
#  'Samsung UA40KU6000': 289,
#  'Samsung UA40KU6300': 290,
#  'Samsung UA40M5000': 291,
#  'Samsung UA40MU6100': 292,
#  'Samsung UA40N5000': 293,
#  'Samsung UA43J5100': 294,
#  'Samsung UA43K5500': 295,
#  'Samsung UA43KU6000': 296,
#  'Samsung UA43NU7100': 297,
#  'Samsung UA48H5100': 298,
#  'Samsung UA48H8000AK': 299,
#  'Samsung UA48J5000AK': 300,
#  'Samsung UA48J5100AK': 301,
#  'Samsung UA48J6300': 302,
#  'Samsung UA48JU6000': 303,
#  'Samsung UA48JU7500': 304,
#  'Samsung UA49K6300': 305,
#  'Samsung UA49KS7000': 306,
#  'Samsung UA49KU6300': 307,
#  'Samsung UA49M6300': 308,
#  'Samsung UA49MU8000': 309,
#  'Samsung UA49N5000': 310,
#  'Samsung UA50JS7200': 311,
#  'Samsung UA50KU6000': 312,
#  'Samsung UA55ES6220': 313,
#  'Samsung UA55J5500': 314,
#  'Samsung UA55JS7200': 315,
#  'Samsung UA55JS9000': 316,
#  'Samsung UA55JU6000': 317,
#  'Samsung UA55JU6400': 318,
#  'Samsung UA55JU7500': 319,
#  'Samsung UA55K5500': 320,
#  'Samsung UA55KU6500': 321,
#  'Samsung UA55MU8000': 322,
#  'Samsung UA58NU7103': 323,
#  'Samsung UA60J6200': 324,
#  'Samsung UA65JS9000': 325,
#  'Samsung UA65JU6600': 326,
#  'Samsung UA65JU7500': 327,
#  'Samsung UA65KU6000': 328,
#  'Samsung UA65MU8000': 329,
#  'Samsung UA70KU6000': 330,
#  'Samsung UA75JU6400': 331,
#  'Sanken SL-E32': 332,
#  'Sharp AQUOS 2T-C40AE1i': 333,
#  'Sharp AQUOS 4T-C40AH1X': 334,
#  'Sharp AQUOS 4T-C50AH1X': 335,
#  'Sharp AQUOS 4T-C60AH1X': 336,
#  'Sharp AQUOS LC-24DC30M': 337,
#  'Sharp AQUOS LC-24LE170i': 338,
#  'Sharp AQUOS LC-24LE175i': 339,
#  'Sharp AQUOS LC-24SA4100i': 340,
#  'Sharp AQUOS LC-29LE507i': 341,
#  'Sharp AQUOS LC-32LE180i': 342,
#  'Sharp AQUOS LC-32LE185i': 343,
#  'Sharp AQUOS LC-32LE265i': 344,
#  'Sharp AQUOS LC-32LE295i': 345,
#  'Sharp AQUOS LC-32SA4100i': 346,
#  'Sharp AQUOS LC-40LE185i': 347,
#  'Sharp AQUOS LC-40LE265M': 348,
#  'Sharp AQUOS LC-40LE275X': 349,
#  'Sharp AQUOS LC-40LE295i': 350,
#  'Sharp AQUOS LC-40LE380X': 351,
#  'Sharp AQUOS LC-40LE600M': 352,
#  'Sharp AQUOS LC-45LE280X': 353,
#  'Sharp AQUOS LC-50LE275X': 354,
#  'Sharp AQUOS LC-50LE580X': 355,
#  'Sharp AQUOS LC-50UE630X': 356,
#  'Sharp AQUOS LC-55LE570X': 357,
#  'Sharp AQUOS LC-58UE1M': 358,
#  'Sharp AQUOS LC-60LE275X': 359,
#  'Sharp AQUOS LC-60UA6800X': 360,
#  'Sharp AQUOS LC-70XU830X': 361,
#  'Sharp AQUOS LC-80XU930X': 362,
#  'Sharp Alexander Slim II 21DXS200MK2': 363,
#  'Sony BRAVIA KD-43X8000E': 364,
#  'Sony BRAVIA KD-49X8000E': 365,
#  'Sony BRAVIA KD-55A8F': 366,
#  'Sony BRAVIA KD-55X8000E': 367,
#  'Sony BRAVIA KD-55X8500D': 368,
#  'Sony BRAVIA KD-55X9004A': 369,
#  'Sony BRAVIA KD-65A8F': 370,
#  'Sony BRAVIA KD-65X9004A': 371,
#  'Sony BRAVIA KD-75X8500F': 372,
#  'Sony BRAVIA KDL-40R350B': 373,
#  'Sony BRAVIA KDL-40W600B': 374,
#  'Sony BRAVIA KDL-40W650D': 375,
#  'Sony BRAVIA KDL-48W650D': 376,
#  'Sony BRAVIA KDL-50W800B': 377,
#  'Sony BRAVIA KDL-55HX750': 378,
#  'Sony BRAVIA KDL-55W650D': 379,
#  'Sony BRAVIA KDL-60W600B': 380,
#  'Sony BRAVIA KLV-32R302C': 381,
#  'Sony BRAVIA KLV-40R352C': 382,
#  'Sony Bravia KDL-40EX650': 383,
#  'TCL 32A3': 384,
#  'TCL 32D2900': 385,
#  'TCL 40A3': 386,
#  'TCL 40D2900': 387,
#  'TCL 55E3': 388,
#  'TCL D2700': 389,
#  'TCL D3000': 390,
#  'TOSHIBA REGZA 23S2400': 391,
#  'TOSHIBA REGZA 24L1600': 392,
#  'TOSHIBA REGZA 24L2600': 393,
#  'TOSHIBA REGZA 24L3650': 394,
#  'TOSHIBA REGZA 24L3750': 395,
#  'TOSHIBA REGZA 32L1600': 396,
#  'TOSHIBA REGZA 32L2400': 397,
#  'TOSHIBA REGZA 32L2550': 398,
#  'TOSHIBA REGZA 32L3650': 399,
#  'TOSHIBA REGZA 32L3750': 400,
#  'TOSHIBA REGZA 32L5400': 401,
#  'TOSHIBA REGZA 32L5650': 402,
#  'TOSHIBA REGZA 32P2400VT': 403,
#  'TOSHIBA REGZA 40L1600': 404,
#  'TOSHIBA REGZA 40L2400': 405,
#  'TOSHIBA REGZA 40L2550': 406,
#  'TOSHIBA REGZA 40L3650': 407,
#  'TOSHIBA REGZA 40L3750': 408,
#  'TOSHIBA REGZA 40L5400': 409,
#  'TOSHIBA REGZA 40L5550': 410,
#  'TOSHIBA REGZA 40L5650': 411,
#  'TOSHIBA REGZA 43L1600': 412,
#  'TOSHIBA REGZA 43L3650': 413,
#  'TOSHIBA REGZA 43L3750': 414,
#  'TOSHIBA REGZA 43L5650': 415,
#  'TOSHIBA REGZA 43U7650': 416,
#  'TOSHIBA REGZA 43U7750': 417,
#  'TOSHIBA REGZA 47L2400': 418,
#  'TOSHIBA REGZA 49L3750': 419,
#  'TOSHIBA REGZA 49L5650': 420,
#  'TOSHIBA REGZA 49U7650': 421,
#  'TOSHIBA REGZA 50L2550': 422,
#  'TOSHIBA REGZA 50L4300VT': 423,
#  'TOSHIBA REGZA 50L5550': 424,
#  'TOSHIBA REGZA 55L5400': 425,
#  'TOSHIBA REGZA 55L5550': 426,
#  'TOSHIBA Regza 40PU200T': 427,
#  'Xiaomi Mi TV 4A 32': 428,
#  'Xiaomi Mi TV 4A 43': 429}

# %%
tv['merek'] = tv['merek'].astype('category')
merek_mapping = _get_category_mapping(tv['merek'])
tv['merek'] = tv['merek'].cat.codes

# %%
merek_mapping
# Out:
# {'AKARI': 0,
#  'AQUA': 1,
#  'Changhong': 2,
#  'Coocaa': 3,
#  'LG': 4,
#  'Mito': 5,
#  'Panasonic': 6,
#  'Philips': 7,
#  'Polytron': 8,
#  'SANKEN': 9,
#  'SANYO': 10,
#  'Samsung': 11,
#  'Sharp': 12,
#  'Sony': 13,
#  'TCL': 14,
#  'TOSHIBA': 15,
#  'Xiaomi': 16}

# %%
tv['tipe'] = tv['tipe'].astype('category')
tipe_mapping = _get_category_mapping(tv['tipe'])
tv['tipe'] = tv['tipe'].cat.codes

# %%
tipe_mapping
# Out:
# {'CRT': 0,
#  'LCD': 1,
#  'LCD, Smart TV': 2,
#  'LED': 3,
#  'LED, Smart TV': 4,
#  'OLED, Smart TV': 5,
#  'Plasma': 6,
#  'QLED, Smart TV': 7}

# %%
tv['ukuran'] = tv['ukuran'].astype('category')
ukuran_mapping = _get_category_mapping(tv['ukuran'])
tv['ukuran'] = tv['ukuran'].cat.codes

# %%
ukuran_mapping
# Out:
# {19: 0,
#  20: 1,
#  21: 2,
#  22: 3,
#  23: 4,
#  24: 5,
#  25: 6,
#  28: 7,
#  29: 8,
#  32: 9,
#  39: 10,
#  40: 11,
#  42: 12,
#  43: 13,
#  45: 14,
#  46: 15,
#  47: 16,
#  48: 17,
#  49: 18,
#  50: 19,
#  55: 20,
#  58: 21,
#  60: 22,
#  65: 23,
#  70: 24,
#  75: 25,
#  79: 26,
#  80: 27,
#  84: 28,
#  86: 29,
#  98: 30}

# %%
tv.head()
# Out:
#    produk  merek  tipe  ukuran    harga
# 0     241      8     3       9  1648000
# 1     338     12     3       5  1091200
# 2     339     12     3       5   400000
# 3     346     12     3       9  1945000
# 4     240      8     3       9  1890000

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
x = tv.drop(['harga'],axis=1)
y = tv['harga']
x.head()
# Out:
#    produk  merek  tipe  ukuran
# 0     241      8     3       9
# 1     338     12     3       5
# 2     339     12     3       5
# 3     346     12     3       9
# 4     240      8     3       9

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.20, random_state=0)

# %%
classifier= RandomForestClassifier(n_estimators=100, max_features=4, random_state=0)

# %%
classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features=4, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
pickle.dump(classifier, open('model.pkl','wb'))

# %%
from sklearn.externals import joblib

def _save_variable(variable, filename):
    """ Save a variable to a file """
    joblib.dump(variable, filename)

# %%
_save_variable(produk_mapping, 'produk.pkl')
_save_variable(merek_mapping, 'merek.pkl')
_save_variable(tipe_mapping, 'tipe.pkl')
_save_variable(ukuran_mapping, 'ukuran.pkl')
